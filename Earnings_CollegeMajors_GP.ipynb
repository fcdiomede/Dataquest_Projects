# %% [markdown]
# ## Visualizing Earnings Based on College Majors

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe(include=["number"])
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads.shape
print(raw_data_count)

recent_grads = recent_grads.dropna()

cleaned_data_count = recent_grads.shape
print(cleaned_data_count)
# Out:
# (173, 21)
# (172, 21)

# %% [markdown]
# ### Using Scatter Plots to Explore Relationships

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter")

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter")

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter")

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter")

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter")

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter")

# %% [markdown]
# ### Observations
#  - There does not seem to be a big difference in increaded major popularity and salary.
#  - There is no correlation between percentage of women in a major and median salary.
#  - There does not seem to be a strong link between number of full-time mployees and median salary.

# %% [markdown]
# ### Histograms to Explore Relations

# %%
fig = plt.figure(figsize=(10,30))
ax1 = fig.add_subplot(8,1,1)
ax2 = fig.add_subplot(8,1,2)
ax3 = fig.add_subplot(8,1,3)
ax4 = fig.add_subplot(8,1,4)
ax5 = fig.add_subplot(8,1,5)
ax6 = fig.add_subplot(8,1,6)
ax7 = fig.add_subplot(8,1,7)
ax8 = fig.add_subplot(8,1,8)

cols = ["Sample_size","Median","Employed","Full_time","ShareWomen",
       "Unemployment_rate","Men","Women"]
axes = [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8]

for i in range(8):
    axes[i].hist(recent_grads[cols[i]])
    axes[i].set_title(cols[i])

# %% [markdown]
# #### Observations
#  - The most common median salary range is from $30,000 to $40,000
#  - The percent of majors that are predominatly male versus perdominatly female are split about 50/50

# %% [markdown]
# ### Scatter Matrix Plot

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[["Sample_size", "Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2990c633c8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2990763d30>]], dtype=object)

# %% [markdown]
#  - There doesn't seem to be a correlation between sample size and ahigher median salary

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f29907a1c18>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2934852d68>]], dtype=object)

# %%
scatter_matrix(recent_grads[["Sample_size", "Men", "Women"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f293485e9b0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2934515b38>]], dtype=object)

# %% [markdown]
#  - Stronger upward trend in sample size and number of men versus number of women

# %%
scatter_matrix(recent_grads[["Median", "ShareWomen"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f29343a09e8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f29342b3128>]], dtype=object)

# %% [markdown]
#  - Weak negative correlation between share of women and median salary

# %%
scatter_matrix(recent_grads[["Full_time", "Median"]])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f29341e2a58>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f2934150828>]], dtype=object)

# %% [markdown]
# ### Bar Plots

# %%
recent_grads[:10].plot.bar(x="Major", y="ShareWomen", legend = False)
recent_grads[163:].plot.bar(x="Major", y="ShareWomen", legend = False)

# %% [markdown]
#  - There is a much higher percentage of women in the last few majors listed- educational, psychology, theater, langauge arts, etc. than in the first few listed- engineering degrees

# %%
recent_grads[:10].plot.bar(x="Major", y="Unemployment_rate", legend = False)
recent_grads[163:].plot.bar(x="Major", y="Unemployment_rate", legend = False)

# %% [markdown]
#  - Nuclear engineering and clinical psychology have the highest rate of unemployment
#  - Petroleum engineering, metallurgical engineering, and astronomy and astrophysics have the lowest rate of unemloyment
#  - Need to look at rates of engineering for each field in relation to how many people in each major

# %% [markdown]
#  -
